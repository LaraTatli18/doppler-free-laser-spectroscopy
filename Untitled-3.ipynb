# %%
from grapher import *

# %%
graph("Data\Zeeman Data\data_z5\\",i1=6100,f1=7000,i2=3800,f2=4300)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# C:\Users\Student\AppData\Local\Temp\ipykernel_9892\2792269637.py:1: SyntaxWarning: invalid escape sequence '\Z'
#   graph("Data\Zeeman Data\data_z5\\",i1=6100,f1=7000,i2=3800,f2=4300)
# Loading Files
# Grouping Data
# Creating first graph

# %%
graph("Data\Zeeman Data\data_z1\\",i1=6100,f1=7000,i2=3400,f2=4000)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# C:\Users\Student\AppData\Local\Temp\ipykernel_9892\4127461857.py:1: SyntaxWarning: invalid escape sequence '\Z'
#   graph("Data\Zeeman Data\data_z1\\",i1=6100,f1=7000,i2=3400,f2=4000)
# Loading Files
# Grouping Data
# Creating first graph

# %%
graph("Data\Zeeman Data\data_z6\\",i1=6200,f1=7100,i2=4000,f2=4400)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# C:\Users\Student\AppData\Local\Temp\ipykernel_9892\419957207.py:1: SyntaxWarning: invalid escape sequence '\Z'
#   graph("Data\Zeeman Data\data_z6\\",i1=6200,f1=7100,i2=4000,f2=4400)
# Loading Files
# Grouping Data
# Creating first graph

# %%
graph("Data\Zeeman Data\data_z7\\",i1=6300,f1=7200,i2=4050,f2=4550)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# C:\Users\Student\AppData\Local\Temp\ipykernel_9892\1998667490.py:1: SyntaxWarning: invalid escape sequence '\Z'
#   graph("Data\Zeeman Data\data_z7\\",i1=6300,f1=7200,i2=4050,f2=4550)
# Loading Files
# Grouping Data
# Creating first graph

# %%
graph("Data\Zeeman Data\data_z4\\",i1=6100,f1=7000,i2=3800,f2=4400)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# C:\Users\Student\AppData\Local\Temp\ipykernel_9892\924688920.py:1: SyntaxWarning: invalid escape sequence '\Z'
#   graph("Data\Zeeman Data\data_z4\\",i1=6100,f1=7000,i2=3800,f2=4400)
# Loading Files
# Grouping Data
# Creating first graph

# %%
graph("Data\Zeeman Data\data_z8\\",i1=6200,f1=7200,i2=4100,f2=4800)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# C:\Users\Student\AppData\Local\Temp\ipykernel_9892\3919761022.py:1: SyntaxWarning: invalid escape sequence '\Z'
#   graph("Data\Zeeman Data\data_z8\\",i1=6200,f1=7200,i2=4100,f2=4800)
# Loading Files
# Grouping Data
# Creating first graph

# %%
graph("Data\Zeeman Data\data_z3\\",i1=6000,f1=7000,i2=3800,f2=4300)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# C:\Users\Student\AppData\Local\Temp\ipykernel_9892\427058073.py:1: SyntaxWarning: invalid escape sequence '\Z'
#   graph("Data\Zeeman Data\data_z3\\",i1=6000,f1=7000,i2=3800,f2=4300)
# Loading Files
# Grouping Data
# Creating first graph

# %%
graph("Data\Zeeman Data\data_z2\\",i1=6100,f1=7000,i2=3600,f2=4300)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# <>:1: SyntaxWarning: invalid escape sequence '\Z'
# C:\Users\Student\AppData\Local\Temp\ipykernel_9892\1194988620.py:1: SyntaxWarning: invalid escape sequence '\Z'
#   graph("Data\Zeeman Data\data_z2\\",i1=6100,f1=7000,i2=3600,f2=4300)
# Loading Files
# Grouping Data
# Creating first graph

# %%
import winsound
frequency = 2300  # Set Frequency To 2500 Hertz
duration = 2000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
